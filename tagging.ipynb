# %%
import pandas as pd
import nltk
from nltk import Tree
from konlpy.tag import *

hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()

# %%
df3 = pd.read_csv('df3.csv',encoding='cp949')
df3.head()
# Out:
#    Unnamed: 0                                            0
# 0           0  채널A 노동조합과 사측이 2020년도 임금협상안을 두고 서로 합의하지 못했다.
# 1           1        채널A 노동조합이 서울지방노동위원회에 노동쟁의 조정신청을 접수했다.
# 2           2              2020년도 임금협상안을 두고 노사가 합의하지 못해서다.
# 3           3             채널A는 노조가 설립되기 전까지 개별 연봉협상을 진행했다.
# 4           4          노조가 설립된 2019년부터 임금 및 단체협상을 진행하고 있다.

# %%
len(df3)
# Out:
# 158

# %%
sentences = df3['0']
sentences[0]
# Out:
# '채널A 노동조합과 사측이 2020년도 임금협상안을 두고 서로 합의하지 못했다.'

# %%
data10 = sentences[0].split()

sent = []
sub = []
obj = []
rel = []

for sentence in data10 :
    tokens = komoran.pos(sentence)
    sent.append(sentence)
    for word, pos in tokens :
        if pos == 'JKO'or pos =='JKS' :
           if pos =='JKS' :
               sub.append(' '.join(sent))   
               sent = []
               
           elif pos =='JKO' :
               obj.append(' '.join(sent))
               sent = [] 
        if pos =='XSV' :
            rel.append(' '.join(sent))
            sent = []
        if pos =='VV' :
            rel.append(' '.join(sent))
            sent = []     

print(sub)
print(obj)
print(rel)
# Out:
# ['채널A 노동조합과 사측이']
# ['2020년도 임금협상안을']
# ['두고', '서로 합의하지']

# %%
sub_text = sub[-1].split()
obj_text = obj[-1].split()
rel_text = rel[-1].split()
print(sub_text)
print(obj_text)
print(rel_text)
# Out:
# ['실제', '검찰청', '내부', '게시판에는', '전국', '각', '지청의', '검사들이']
# ['실명으로', '중수청', '설립', '반대', '글을']
# ['올리고']

# %% [markdown]
# #### 문장에서 sub, obj, rel 분리

# %%
subject = []
object = []
relation =[]

for sentence in sub_text :
    tokens = komoran.pos(sentence)
    pos_tags = [pos for word, pos in tokens]
    if 'JKS' not in pos_tags :
        subject.append(sentence)
    else :
        word_list = [word for word, pos in tokens if pos != 'JKS']
        joined_word = ''.join(word_list)
        subject.append(joined_word)
        
for sentence in obj_text :
    tokens = komoran.pos(sentence)
    pos_tags = [pos for word, pos in tokens]
    if 'JKO' not in pos_tags :
        continue
    else :
        word_list = [word for word, pos in tokens if pos != 'JKO']
        joined_word = ''.join(word_list)
        object.append(joined_word)
        
for sentence in rel_text :
    tokens = komoran.pos(sentence)
    pos_tags = [pos for word, pos in tokens]
    if 'XSV' not in pos_tags  :
        continue
    else :
        word_list = [word for word, pos in tokens if pos == 'NNG']
        joined_word = ''.join(word_list)
        relation.append(joined_word)
        
for sentence in rel_text :
    tokens = komoran.pos(sentence)
    pos_tags = [pos for word, pos in tokens]
    if 'VV' not in pos_tags :
        continue
    else :
        relation.append(sentence)
        
        
print(subject)
print(object)
print(relation)
# Out:
# ['채널A', '노동조합과', '사측']
# ['임금협상안']
# ['합의']

# %% [markdown]
# #### 분리한 것에서 필요한 단어 추출

# %%
data10 = sentences[0].split()

sent = []
sub = []
obj = []
rel = []

for sentence in data10 :
    tokens = komoran.pos(sentence)
    sent.append(sentence)
    for word, pos in tokens :
        if pos == 'JKO'or pos =='JKS' :
           if pos =='JKS' :
               sub.append(' '.join(sent))   
               sent = []
               
           elif pos =='JKO' :
               obj.append(' '.join(sent))
               sent = [] 
        if pos =='XSV' :
            rel.append(' '.join(sent))
            sent = []
        if pos =='VV' :
            rel.append(' '.join(sent))
            sent = []    
            
sub_text = sub[-1].split()
obj_text = obj[-1].split()
rel_text = rel[-1].split()           
            
subject = []
object = []
relation =[]

for sentence in sub_text :
    tokens = komoran.pos(sentence)
    pos_tags = [pos for word, pos in tokens]
    if 'JKS' not in pos_tags :
        subject.append(sentence)
    else :
        word_list = [word for word, pos in tokens if pos != 'JKS']
        joined_word = ''.join(word_list)
        subject.append(joined_word)
        
for sentence in obj_text :
    tokens = komoran.pos(sentence)
    pos_tags = [pos for word, pos in tokens]
    if 'JKO' not in pos_tags :
        continue
    else :
        word_list = [word for word, pos in tokens if pos != 'JKO']
        joined_word = ''.join(word_list)
        object.append(joined_word)
        
for sentence in rel_text :
    tokens = komoran.pos(sentence)
    pos_tags = [pos for word, pos in tokens]
    if 'XSV' not in pos_tags  :
        continue
    else :
        word_list = [word for word, pos in tokens if pos == 'NNG']
        joined_word = ''.join(word_list)
        relation.append(joined_word)
        
for sentence in rel_text :
    tokens = komoran.pos(sentence)
    pos_tags = [pos for word, pos in tokens]
    if 'VV' not in pos_tags :
        continue
    else :
        relation.append(sentence)


        
print("subject :",subject)
print("object :",object)
print("relation :",relation)
print(sentences[0])
# Out:
# subject : ['채널A', '노동조합과', '사측']
# object : ['임금협상안']
# relation : ['합의']
# 채널A 노동조합과 사측이 2020년도 임금협상안을 두고 서로 합의하지 못했다.

# %%
for df_sent in sentences :
    data10 = df_sent.split()
    
    sent = []
    sub = []
    obj = []
    rel = []

    for sentence in data10 :
        tokens = komoran.pos(sentence)
        sent.append(sentence)
        for word, pos in tokens :
            if pos == 'JKO'or pos =='JKS' :
                if pos =='JKS' :
                    sub.append(' '.join(sent))   
                    sent = []
                elif pos =='JKO' :
                    obj.append(' '.join(sent))
                    sent = [] 
            if pos =='XSV' :
                rel.append(' '.join(sent))
                sent = []
            if pos =='VV' :
                rel.append(' '.join(sent))
                sent = []    
            
    sub_text = sub[-1].split()
    obj_text = obj[-1].split()
    rel_text = rel[-1].split()           
            
    subject = []
    object = []
    relation =[]

    for sentence in sub_text :
        tokens = komoran.pos(sentence)
        pos_tags = [pos for word, pos in tokens]
        if 'JKS' not in pos_tags :
            subject.append(sentence)
        else :
            word_list = [word for word, pos in tokens if pos != 'JKS']
            joined_word = ''.join(word_list)
            subject.append(joined_word)
        
    for sentence in obj_text :
        tokens = komoran.pos(sentence)
        pos_tags = [pos for word, pos in tokens]
        if 'JKO' not in pos_tags :
            continue
        else :
            word_list = [word for word, pos in tokens if pos != 'JKO']
            joined_word = ''.join(word_list)
            object.append(joined_word)
        
        
    for sentence in rel_text :
        tokens = komoran.pos(sentence)
        pos_tags = [pos for word, pos in tokens]
        if 'XSV' not in pos_tags  :
            continue
        else :
            word_list = [word for word, pos in tokens if pos == 'NNG']
            joined_word = ''.join(word_list)
            relation.append(joined_word)
        
    for sentence in rel_text :
        tokens = komoran.pos(sentence)
        pos_tags = [pos for word, pos in tokens]
        if 'VV' not in pos_tags :
            continue
        else :
            relation.append(sentence)
        
    subject = ' '.join(subject)
    object = ' '.join(object)
    relation = ' '.join(relation)
    data = {
        'text' : [df_sent],
        'subject' : subject,
        'object' : object,
        'relation' : relation
}
    df = df.append(pd.DataFrame(data),ignore_index=True)
    data={}

# %%
import pandas as pd

df = pd.DataFrame(columns=['text', 'subject', 'object', 'relation'])

for df_sent in sentences:
    data10 = df_sent.split()
    sent = []
    sub = []
    obj = []
    rel = []

    for sentence in data10:
        tokens = komoran.pos(sentence)
        sent.append(sentence)
        for word, pos in tokens:
            if pos == 'JKO' or pos == 'JKS':
                if pos == 'JKS':
                    sub.append(' '.join(sent))
                    sent = []
                elif pos == 'JKO':
                    obj.append(' '.join(sent))
                    sent = []
            if pos == 'XSV' or pos == 'VV':
                rel.append(' '.join(sent))
                sent = []

    sub_text = sub[-1].split()
    obj_text = obj[-1].split()
    rel_text = rel[-1].split()

    subject = []
    object = []
    relation = []

    for sentence in sub_text:
        tokens = komoran.pos(sentence)
        pos_tags = [pos for word, pos in tokens]
        if 'JKS' not in pos_tags:
            subject.append(sentence)
        else:
            word_list = [word for word, pos in tokens if pos != 'JKS']
            joined_word = ''.join(word_list)
            subject.append(joined_word)

    for sentence in obj_text:
        tokens = komoran.pos(sentence)
        pos_tags = [pos for word, pos in tokens]
        if 'JKO' not in pos_tags:
            continue
        else:
            word_list = [word for word, pos in tokens if pos != 'JKO']
            joined_word = ''.join(word_list)
            object.append(joined_word)

    for sentence in rel_text:
        tokens = komoran.pos(sentence)
        pos_tags = [pos for word, pos in tokens]
        if 'XSV' in pos_tags:
            word_list = [word for word, pos in tokens if pos == 'NNG']
            joined_word = ''.join(word_list)
            relation.append(joined_word)
        elif 'VV' in pos_tags:
            relation.append(sentence)

    subject = ' '.join(subject)
    object = ' '.join(object)
    relation = ' '.join(relation)

    data = {
        'text': [df_sent],
        'subject': subject,
        'object': object,
        'relation': relation
    }
    df = df.append(pd.DataFrame(data), ignore_index=True)

print(df)
# Out:
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
#                                                   text  \
# 0          채널A 노동조합과 사측이 2020년도 임금협상안을 두고 서로 합의하지 못했다.
# 1                채널A 노동조합이 서울지방노동위원회에 노동쟁의 조정신청을 접수했다.
# 2                      2020년도 임금협상안을 두고 노사가 합의하지 못해서다.
# 3                     채널A는 노조가 설립되기 전까지 개별 연봉협상을 진행했다.
# 4                  노조가 설립된 2019년부터 임금 및 단체협상을 진행하고 있다.
# ..                                                 ...
# 153  한국일보는 1면 머리기사 제목(또 역대급 공시가…‘보유세 쇼크’ 현실화하나)에 ‘보...
# 154  호반그룹이나 창업주인 김상열 회장 관련 미담을 전하는 서울신문 기사가 인수 이전에 ...
# 155                다른 언론사들이 보도한 이슈에는 더 큰 지면과 분량을 할애했다.
# 156  김 회장은 이로써 서울신문과 EBN, 전자신문이 속한 서울미디어홀딩스 회장이자 서울...
# 157  서울신문은 이달 서울 중구 프레스센터의 기존 서울신문 사장실을 회장실로 바꿔 김 회...
#
#                             subject object relation
# 0                      채널A 노동조합과 사측  임금협상안       합의
# 1                          채널A 노동조합   조정신청       접수
# 2                                노사  임금협상안       합의
# 3                           채널A는 노조   연봉협상       진행
# 4                                노조   단체협상       진행
# ..                              ...    ...      ...
# 153  한국일보는 1면 머리기사 제목(또 역대급 공시…‘보유세     우려     담았다.
# 154                         서울신문 기사     미담     늘었다.
# 155                         다른 언론사들     분량       할애
# 156       김 회장은 이로써 서울신문과 EBN, 전자신문     회장      됐다.
# 157                            김 회장    사장실    전해졌다.
#
# [158 rows x 4 columns]
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)
# C:\Users\erich\AppData\Local\Temp\ipykernel_7200\1106886095.py:75: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame(data), ignore_index=True)

# %%
df.to_csv('new_data.csv',encoding='cp949')
